# %%
from seaborn import load_dataset

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x = [1, 2, 3, 4, 5]
y = [10, 12, 14, 18, 15]

# %%
plt.scatter(x, y)

# %%
z = [1, 2, 3, 4, 5]
k = [10, 12, 14, 18, 15]
